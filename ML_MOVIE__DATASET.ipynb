# %% [markdown]
# <a href="https://colab.research.google.com/github/psb2110-glitch/MOVIE_DATA/blob/main/ML_MOVIE__DATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/ML/ML_MOVIE/ML_MOVIE DATA.csv')
print(df)
# Out:
# Mounted at /content/drive
#    Movie_id                                             Review Sentiment  \
# 0      2501  One of the other reviewers has mentioned that ...  positive
# 1      2502  A wonderful little production. <br /><br />The...  positive
# 2      2503  I thought this was a wonderful way to spend ti...  positive
# 3      2504  Basically there's a family where a little boy ...  negative
# 4      2505  Petter Mattei's "Love in the Time of Money" is...  positive
# 5      2506  Probably my all-time favorite movie  a story o...  positive
# 6      2507  I sure would like to see a resurrection of a u...  positive
# 7      2508  This show was an amazing  fresh & innovative i...  negative
# 8      2509  Encouraged by the positive comments about this...  negative
# 9      2510  If you like original gut wrenching laughter yo...  positive
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5
# 6        NaN
# 7        NaN
# 8        NaN
# ...
