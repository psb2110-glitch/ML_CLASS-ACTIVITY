# %% [markdown]
# <a href="https://colab.research.google.com/github/psb2110-glitch/HOUSING_DATA/blob/main/ML_HOUSING_DATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/ML/ML_HOUSING/ML_HOUSING DATA.csv')
print(df)
# Out:
# Mounted at /content/drive
#    House_id  bhk              type                              locality  \
# 0      1010    3         Apartment   Lak and Hanware The Residency Tower
# 1      1011    2         Apartment     Radheya Sai Enclave Building No 2
# 2      1012    2         Apartment                         Romell Serene
# 3      1013    2         Apartment  Soundlines Codename Urban Rainforest
# 4      1014    5             Villa                        Agami Estancia
# 5      1015    3         Apartment                       Sanghvi Infenia
# 6      1016    1         Apartment                 Shubh Shreeji Heights
# 7      1017    2         Apartment            Aplite Greenstone Heritage
# 8      1018    1  Studio Apartment                  A Plus Golden Corner
# 9      1019    2         Apartment                       Unimont Imperia
#
#    area(in sq ft)  price price_unit          region
# 0             685   2.50         Cr    Andheri West
# ...
